# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from matplotlib import pyplot as pyplot
from warnings import simplefilter
import joblib
import time
import warnings
warnings.filterwarnings('ignore')
#显示所有的列
pd.set_option('display.max_columns', None)

#显示所有的行
pd.set_option('display.max_rows', None)

#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
# 加载训练数据和测试数据
dftrain = pd.read_csv("./train70_reduced.csv")

simplefilter(action='ignore', category=FutureWarning)
seed = 7

# 获取和打印数据总的类别数
class_names = dftrain.target.unique()
print(class_names)

# 转换为分类数据,即将数据中标签形式数据转换为可编码类型
dftrain = dftrain.astype('category')  # 可以指定特定的列转为分类数据 df['col1'] = df['col1'].astype('category')

# 找出和打印分类标签列
cat_columns = dftrain.select_dtypes(['category']).columns
print('cat_columns ------------', cat_columns)

# 将标签列转换为编码数字格式，以方便输入模型
dftrain[cat_columns] = dftrain[cat_columns].apply(lambda x: x.cat.codes)

# 分离目标y和特征列x
x_columns = dftrain.columns.drop('target')
x_train = dftrain[x_columns].values
y_train = dftrain['target'].values
# Out:
# ['legitimate' 'dos' 'malformed' 'bruteforce' 'slowite' 'flood']
# cat_columns ------------ Index(['tcp.flags', 'tcp.time_delta', 'tcp.len', 'mqtt.conack.flags',
#        'mqtt.conack.flags.reserved', 'mqtt.conack.flags.sp', 'mqtt.conack.val',
#        'mqtt.conflag.cleansess', 'mqtt.conflag.passwd', 'mqtt.conflag.qos',
#        'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.uname',
#        'mqtt.conflag.willflag', 'mqtt.conflags', 'mqtt.dupflag',
#        'mqtt.hdrflags', 'mqtt.kalive', 'mqtt.len', 'mqtt.msg', 'mqtt.msgid',
#        'mqtt.msgtype', 'mqtt.proto_len', 'mqtt.protoname', 'mqtt.qos',
#        'mqtt.retain', 'mqtt.sub.qos', 'mqtt.suback.qos', 'mqtt.ver',
#        'mqtt.willmsg', 'mqtt.willmsg_len', 'mqtt.willtopic',
#        'mqtt.willtopic_len', 'target'],
#       dtype='object')

# %%
import optuna
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# 定义要优化的超参数空间
def objective(trial):
    hidden_layer_sizes = tuple(
        trial.suggest_categorical('hidden_layer_sizes', [(10,), (50,), (50,50)])
    )
    activation = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    alpha = trial.suggest_loguniform('alpha', 1e-6, 1e1)
    learning_rate_init = trial.suggest_loguniform('learning_rate_init', 1e-2,1e1)
    max_iter = trial.suggest_categorical('max_iter', [100, 200])

    # 创建MLP分类器对象
    mlp = MLPClassifier(
        hidden_layer_sizes=hidden_layer_sizes,
        activation=activation,
        alpha=alpha,
        learning_rate_init=learning_rate_init,
        max_iter=max_iter
    )

    # 计算交叉验证分数
    score = cross_val_score(mlp, x_train, y_train, cv=3).mean()

    return score

# 创建Optuna优化对象
study = optuna.create_study(direction='minimize')

# 开始优化
study.optimize(objective, n_trials=100,n_jobs=12)

# 输出最优参数和得分
print("Best parameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2023-04-12 11:54:57,221] A new study created in memory with name: no-name-0c409947-4bbd-4d10-a6af-179d547706bf
# [I 2023-04-12 11:59:25,456] Trial 9 finished with value: 0.5962846638110388 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'relu', 'alpha': 0.2900674624154826, 'learning_rate_init': 0.15267979821793826, 'max_iter': 100}. Best is trial 9 with value: 0.5962846638110388.
# [I 2023-04-12 12:00:01,573] Trial 11 finished with value: 0.5000043169505061 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'relu', 'alpha': 5.97021998869405, 'learning_rate_init': 7.805492021829246, 'max_iter': 100}. Best is trial 11 with value: 0.5000043169505061.
# [I 2023-04-12 12:01:10,227] Trial 4 finished with value: 0.7096085454513837 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'logistic', 'alpha': 0.3152206015553121, 'learning_rate_init': 0.6077835056191088, 'max_iter': 200}. Best is trial 11 with value: 0.5000043169505061.
# [I 2023-04-12 12:01:32,902] Trial 2 finished with value: 0.7673219167569751 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'tanh', 'alpha': 0.019493761740754494, 'learning_rate_init': 0.07925242973746062, 'max_iter': 200}. Best is trial 11 with value: 0.5000043169505061.
# [I 2023-04-12 12:04:01,908] Trial 1 finished with value: 0.46450603293833237 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'relu', 'alpha': 0.0004911912738556023, 'learning_rate_init': 1.605148512290146, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:04:17,704] Trial 3 finished with value: 0.6836768927316607 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'alpha': 0.00026925947310719534, 'learning_rate_init': 2.964741846076183, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:05:16,542] Trial 7 finished with value: 0.6327984911417133 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 0.006943484585101158, 'learning_rate_init': 3.6823159963610497, 'max_iter': 200}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:07:50,901] Trial 6 finished with value: 0.8979304274495723 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'relu', 'alpha': 0.00278873393465643, 'learning_rate_init': 0.010242571183298963, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:09:07,089] Trial 0 finished with value: 0.48112130052168284 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 0.0006684417435809556, 'learning_rate_init': 5.105274292558188, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:09:31,762] Trial 16 finished with value: 0.697214737089082 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'logistic', 'alpha': 0.10171251559078319, 'learning_rate_init': 0.2860989817303382, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:10:12,832] Trial 17 finished with value: 0.6781856089150377 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'logistic', 'alpha': 0.01708219113794213, 'learning_rate_init': 0.3931477956855175, 'max_iter': 200}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:10:41,792] Trial 12 finished with value: 0.642842658751494 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 0.0001853402684674885, 'learning_rate_init': 3.011150656508942, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:10:54,197] Trial 10 finished with value: 0.6678250518707186 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'tanh', 'alpha': 0.00031328593399335315, 'learning_rate_init': 0.19613991852350854, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:11:20,621] Trial 14 finished with value: 0.6132076769763871 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'alpha': 0.00044291787095107474, 'learning_rate_init': 2.179678454785106, 'max_iter': 200}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:12:11,681] Trial 15 finished with value: 0.8047538542871947 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'alpha': 0.0029137910952254306, 'learning_rate_init': 0.01839979244873906, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:14:34,535] Trial 5 finished with value: 0.8306208714967726 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 1.5660156031278375e-06, 'learning_rate_init': 0.07952780416097836, 'max_iter': 200}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:16:37,727] Trial 20 finished with value: 0.5873830857026401 and parameters: {'hidden_layer_sizes': (10,), 'activation': 'logistic', 'alpha': 1.2250913589559717e-06, 'learning_rate_init': 2.0448448279158637, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:17:19,650] Trial 26 finished with value: 0.6603093561529519 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 5.534217346676747e-06, 'learning_rate_init': 0.913599922285677, 'max_iter': 100}. Best is trial 1 with value: 0.46450603293833237.
# [I 2023-04-12 12:18:08,941] Trial 21 finished with value: 0.3922014289106175 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 7.99600224618778e-06, 'learning_rate_init': 1.2411092097327785, 'max_iter': 200}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:18:14,068] Trial 8 finished with value: 0.46450603293833237 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 1.3792398385945068e-06, 'learning_rate_init': 2.439729577749878, 'max_iter': 200}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:18:19,446] Trial 13 finished with value: 0.5000043169505061 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 0.03291247580575623, 'learning_rate_init': 4.448727899529983, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:18:36,737] Trial 25 finished with value: 0.588415463316713 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'alpha': 6.355719027810473e-06, 'learning_rate_init': 1.0655766801444806, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:20:14,887] Trial 22 finished with value: 0.5010706037255283 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'alpha': 1.3353036545429535e-06, 'learning_rate_init': 1.6022850923409335, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:21:00,412] Trial 23 finished with value: 0.6113679922155703 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'alpha': 3.396440525047394e-06, 'learning_rate_init': 1.1925885339561175, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:21:02,280] Trial 24 finished with value: 0.6097363129523266 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'alpha': 8.630202797909522e-06, 'learning_rate_init': 1.2456844343714284, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:23:47,099] Trial 27 finished with value: 0.6785825910231384 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 2.0279944937944298e-05, 'learning_rate_init': 1.0063936054099596, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:25:16,391] Trial 19 finished with value: 0.7908143225379426 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'tanh', 'alpha': 5.8984482721120675e-06, 'learning_rate_init': 0.02767887008352149, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:25:36,312] Trial 28 finished with value: 0.5934235855750056 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 2.0813374383378325e-05, 'learning_rate_init': 9.271784026658155, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:26:16,526] Trial 18 finished with value: 0.8414736245214848 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 0.484496238159258, 'learning_rate_init': 0.010652551955910984, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:27:09,725] Trial 30 finished with value: 0.4645060329383323 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 2.7316742206780374e-05, 'learning_rate_init': 1.2022745440457143, 'max_iter': 200}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:27:19,300] Trial 29 finished with value: 0.5512719039058626 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 2.7387604097442907e-05, 'learning_rate_init': 9.916892547428066, 'max_iter': 100}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:28:34,546] Trial 32 finished with value: 0.4645060329383323 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 3.027885933390429e-05, 'learning_rate_init': 1.1664791694170815, 'max_iter': 200}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:28:51,628] Trial 33 finished with value: 0.4645060329383323 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha': 3.787458285473322e-05, 'learning_rate_init': 1.342034528980337, 'max_iter': 200}. Best is trial 21 with value: 0.3922014289106175.
# [I 2023-04-12 12:28:52,301] Trial 35 finished with value: 0.4645060329383323 and parameters: {'hidden_layer_sizes': (50, 50), 'activation': 'logistic', 'alpha':